# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %%
#importing the dataset
df = pd.read_csv('Churn_Modelling.csv', index_col='RowNumber')
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
X_columns = df.columns.tolist()[2:12]
y_columns = df.columns.tolist()[-1:]
print(f'All columns: {df.columns.tolist()}')
print()
print(f'X values: {X_columns}')
print()
print(f'y values: {y_columns}')
# Out:
# All columns: ['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
#
# X values: ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
#
# y values: ['Exited']

# %%
X = df[X_columns].values   # Credit Score through Estimated Salary
y = df[y_columns].values   # Exited

# %%
# Encoding categorical (string based) data. Country: there are 3 options: France, Spain and Germany
# This will convert those strings into scalar values for analysis

print(X[:8,1], '... will now become: ')

from sklearn.preprocessing import LabelEncoder
label_X_country_encoder = LabelEncoder()
X[:,1] = label_X_country_encoder.fit_transform(X[:,1])

print(X[:8,1])
# Out:
# ['France' 'Spain' 'France' 'France' 'Spain' 'Spain' 'France' 'Germany'] ... will now become:
# [0 2 0 0 2 2 0 1]

# %%
# We will do the same thing for gender. this will be binary in this dataset

print(X[:6,2], '... will now become: ')

from sklearn.preprocessing import LabelEncoder
label_X_gender_encoder = LabelEncoder()
X[:,2] = label_X_gender_encoder.fit_transform(X[:,2])

print(X[:6,2])
# Out:
# ['Female' 'Female' 'Female' 'Female' 'Female' 'Male'] ... will now become:
# [0 0 0 0 0 1]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

pipeline = Pipeline(
    [('Categorizer', ColumnTransformer(
         [ # Gender
          ("Gender Label encoder", OneHotEncoder(categories='auto', drop='first'), [2]),
           # Geography
          ("Geography One Hot", OneHotEncoder(categories='auto', drop='first'), [1])
         ], remainder='passthrough', n_jobs=1)),
     # Standard Scaler for the classifier
    ('Normalizer', StandardScaler())
    ])

# %%
X = pipeline.fit_transform(X)

# %%
# Splitting the dataset into the Training and Testing set.

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(f'training shapes: {X_train.shape}, {y_train.shape}')
print(f'testing shapes: {X_test.shape}, {y_test.shape}')
# Out:
# training shapes: (8000, 11), (8000, 1)
# testing shapes: (2000, 11), (2000, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

classifier = Sequential()

# %%
# This adds the input layer (by specifying input dimension) AND the first hidden layer (units)
classifier.add(Dense(6, activation = 'relu', input_shape = (X_train.shape[1], )))
classifier.add(Dropout(rate=0.1))

# %%
# Adding the second hidden layer
# Notice that we do not need to specify input dim. 
classifier.add(Dense(6, activation = 'relu')) 
classifier.add(Dropout(rate=0.1))

# %%
# Adding the output layer
# Notice that we do not need to specify input dim. 
# we have an output of 1 node, which is the the desired dimensions of our output (stay with the bank or not)
# We use the sigmoid because we want probability outcomes
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 72
# _________________________________________________________________
# dropout (Dropout)            (None, 6)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
history = classifier.fit(X_train, y_train, batch_size=32, epochs=200, validation_split=0.1, verbose=2)
# Out:
# Epoch 1/200
# 225/225 - 6s - loss: 0.5964 - accuracy: 0.7465 - val_loss: 0.5192 - val_accuracy: 0.7950
# Epoch 2/200
# 225/225 - 1s - loss: 0.5105 - accuracy: 0.7958 - val_loss: 0.4750 - val_accuracy: 0.7950
# Epoch 3/200
# 225/225 - 1s - loss: 0.4853 - accuracy: 0.7962 - val_loss: 0.4567 - val_accuracy: 0.7950
# Epoch 4/200
# 225/225 - 1s - loss: 0.4691 - accuracy: 0.7961 - val_loss: 0.4445 - val_accuracy: 0.7950
# Epoch 5/200
# 225/225 - 1s - loss: 0.4609 - accuracy: 0.7961 - val_loss: 0.4367 - val_accuracy: 0.7950
# Epoch 6/200
# 225/225 - 2s - loss: 0.4158 - accuracy: 0.8054 - val_loss: 0.3846 - val_accuracy: 0.8050
# Epoch 51/200
# 225/225 - 1s - loss: 0.4167 - accuracy: 0.8076 - val_loss: 0.3825 - val_accuracy: 0.8062
# Epoch 52/200
# 225/225 - 1s - loss: 0.4126 - accuracy: 0.8099 - val_loss: 0.3815 - val_accuracy: 0.8075
# Epoch 53/200
# 225/225 - 1s - loss: 0.4081 - accuracy: 0.8104 - val_loss: 0.3793 - val_accuracy: 0.8087
# Epoch 54/200
# 225/225 - 1s - loss: 0.4071 - accuracy: 0.8101 - val_loss: 0.3772 - val_accuracy: 0.8100
# Epoch 55/200
# 225/225 - 1s - loss: 0.4069 - accuracy: 0.8119 - val_loss: 0.3754 - val_accuracy: 0.8100
# Epoch 56/200
# 225/225 - 1s - loss: 0.4065 - accuracy: 0.8104 - val_loss: 0.3741 - val_accuracy: 0.8112
# Epoch 57/200
# 225/225 - 1s - loss: 0.4022 - accuracy: 0.8154 - val_loss: 0.3715 - val_accuracy: 0.8100
# Epoch 58/200
# 225/225 - 1s - loss: 0.4014 - accuracy: 0.8129 - val_loss: 0.3692 - val_accuracy: 0.8100
# Epoch 59/200
# 225/225 - 1s - loss: 0.3965 - accuracy: 0.8147 - val_loss: 0.3669 - val_accuracy: 0.8100
# Epoch 60/200
# 225/225 - 1s - loss: 0.4021 - accuracy: 0.8135 - val_loss: 0.3656 - val_accuracy: 0.8100
# Epoch 61/200
# 225/225 - 1s - loss: 0.4017 - accuracy: 0.8204 - val_loss: 0.3667 - val_accuracy: 0.8100
# Epoch 62/200
# 225/225 - 1s - loss: 0.4023 - accuracy: 0.8133 - val_loss: 0.3663 - val_accuracy: 0.8100
# Epoch 63/200
# 225/225 - 1s - loss: 0.3977 - accuracy: 0.8244 - val_loss: 0.3646 - val_accuracy: 0.8462
# Epoch 64/200
# 225/225 - 1s - loss: 0.3959 - accuracy: 0.8331 - val_loss: 0.3649 - val_accuracy: 0.8475
# Epoch 65/200
# 225/225 - 1s - loss: 0.3959 - accuracy: 0.8382 - val_loss: 0.3636 - val_accuracy: 0.8475
# Epoch 66/200
# 225/225 - 1s - loss: 0.3941 - accuracy: 0.8386 - val_loss: 0.3631 - val_accuracy: 0.8500
# Epoch 67/200
# 225/225 - 1s - loss: 0.3911 - accuracy: 0.8422 - val_loss: 0.3616 - val_accuracy: 0.8487
# Epoch 68/200
# 225/225 - 1s - loss: 0.3937 - accuracy: 0.8421 - val_loss: 0.3615 - val_accuracy: 0.8512
# Epoch 69/200
# 225/225 - 1s - loss: 0.3904 - accuracy: 0.8438 - val_loss: 0.3604 - val_accuracy: 0.8500
# Epoch 70/200
# 225/225 - 1s - loss: 0.3936 - accuracy: 0.8450 - val_loss: 0.3609 - val_accuracy: 0.8487
# Epoch 71/200
# 225/225 - 1s - loss: 0.3953 - accuracy: 0.8438 - val_loss: 0.3608 - val_accuracy: 0.8550
# Epoch 72/200
# 225/225 - 1s - loss: 0.3943 - accuracy: 0.8432 - val_loss: 0.3603 - val_accuracy: 0.8550
# Epoch 73/200
# 225/225 - 1s - loss: 0.3936 - accuracy: 0.8408 - val_loss: 0.3594 - val_accuracy: 0.8537
# Epoch 74/200
# 225/225 - 1s - loss: 0.3927 - accuracy: 0.8433 - val_loss: 0.3586 - val_accuracy: 0.8537
# Epoch 75/200
# 225/225 - 1s - loss: 0.3966 - accuracy: 0.8429 - val_loss: 0.3590 - val_accuracy: 0.8537
# Epoch 76/200
# 225/225 - 1s - loss: 0.3928 - accuracy: 0.8424 - val_loss: 0.3590 - val_accuracy: 0.8537
# Epoch 77/200
# 225/225 - 1s - loss: 0.3929 - accuracy: 0.8442 - val_loss: 0.3589 - val_accuracy: 0.8537
# Epoch 78/200
# 225/225 - 1s - loss: 0.3948 - accuracy: 0.8454 - val_loss: 0.3591 - val_accuracy: 0.8500
# Epoch 79/200
# 225/225 - 1s - loss: 0.3944 - accuracy: 0.8460 - val_loss: 0.3585 - val_accuracy: 0.8512
# Epoch 80/200
# 225/225 - 1s - loss: 0.3911 - accuracy: 0.8439 - val_loss: 0.3577 - val_accuracy: 0.8512
# Epoch 81/200
# 225/225 - 1s - loss: 0.3853 - accuracy: 0.8458 - val_loss: 0.3572 - val_accuracy: 0.8512
# Epoch 82/200
# 225/225 - 1s - loss: 0.3904 - accuracy: 0.8451 - val_loss: 0.3577 - val_accuracy: 0.8525
# Epoch 83/200
# 225/225 - 1s - loss: 0.3945 - accuracy: 0.8431 - val_loss: 0.3569 - val_accuracy: 0.8525
# Epoch 84/200
# 225/225 - 1s - loss: 0.3891 - accuracy: 0.8429 - val_loss: 0.3571 - val_accuracy: 0.8525
# Epoch 85/200
# 225/225 - 1s - loss: 0.3946 - accuracy: 0.8454 - val_loss: 0.3568 - val_accuracy: 0.8525
# Epoch 86/200
# 225/225 - 1s - loss: 0.3951 - accuracy: 0.8428 - val_loss: 0.3567 - val_accuracy: 0.8525
# Epoch 87/200
# 225/225 - 1s - loss: 0.3940 - accuracy: 0.8414 - val_loss: 0.3574 - val_accuracy: 0.8525
# Epoch 88/200
# 225/225 - 1s - loss: 0.3915 - accuracy: 0.8449 - val_loss: 0.3568 - val_accuracy: 0.8512
# Epoch 89/200
# 225/225 - 1s - loss: 0.3949 - accuracy: 0.8440 - val_loss: 0.3569 - val_accuracy: 0.8525
# Epoch 90/200
# 225/225 - 1s - loss: 0.3914 - accuracy: 0.8426 - val_loss: 0.3568 - val_accuracy: 0.8525
# Epoch 91/200
# 225/225 - 1s - loss: 0.3943 - accuracy: 0.8446 - val_loss: 0.3565 - val_accuracy: 0.8525
# Epoch 92/200
# 225/225 - 1s - loss: 0.3986 - accuracy: 0.8439 - val_loss: 0.3572 - val_accuracy: 0.8525
# Epoch 93/200
# 225/225 - 1s - loss: 0.3917 - accuracy: 0.8462 - val_loss: 0.3569 - val_accuracy: 0.8512
# Epoch 94/200
# 225/225 - 1s - loss: 0.3914 - accuracy: 0.8456 - val_loss: 0.3564 - val_accuracy: 0.8512
# Epoch 95/200
# 225/225 - 1s - loss: 0.4017 - accuracy: 0.8426 - val_loss: 0.3570 - val_accuracy: 0.8512
# Epoch 96/200
# 225/225 - 1s - loss: 0.3915 - accuracy: 0.8440 - val_loss: 0.3568 - val_accuracy: 0.8525
# Epoch 97/200
# 225/225 - 1s - loss: 0.3912 - accuracy: 0.8444 - val_loss: 0.3565 - val_accuracy: 0.8512
# Epoch 98/200
# 225/225 - 1s - loss: 0.3924 - accuracy: 0.8435 - val_loss: 0.3567 - val_accuracy: 0.8500
# Epoch 99/200
# 225/225 - 1s - loss: 0.3860 - accuracy: 0.8456 - val_loss: 0.3555 - val_accuracy: 0.8537
# Epoch 100/200
# 225/225 - 1s - loss: 0.3913 - accuracy: 0.8443 - val_loss: 0.3562 - val_accuracy: 0.8537
# Epoch 101/200
# 225/225 - 1s - loss: 0.3960 - accuracy: 0.8444 - val_loss: 0.3560 - val_accuracy: 0.8475
# Epoch 102/200
# 225/225 - 1s - loss: 0.3906 - accuracy: 0.8460 - val_loss: 0.3561 - val_accuracy: 0.8525
# Epoch 103/200
# 225/225 - 1s - loss: 0.3892 - accuracy: 0.8464 - val_loss: 0.3553 - val_accuracy: 0.8500
# Epoch 104/200
# 225/225 - 1s - loss: 0.3884 - accuracy: 0.8444 - val_loss: 0.3541 - val_accuracy: 0.8525
# Epoch 105/200
# 225/225 - 1s - loss: 0.3916 - accuracy: 0.8454 - val_loss: 0.3541 - val_accuracy: 0.8537
# Epoch 106/200
# 225/225 - 1s - loss: 0.3877 - accuracy: 0.8474 - val_loss: 0.3547 - val_accuracy: 0.8512
# Epoch 107/200
# 225/225 - 1s - loss: 0.3889 - accuracy: 0.8467 - val_loss: 0.3542 - val_accuracy: 0.8500
# Epoch 108/200
# 225/225 - 1s - loss: 0.3957 - accuracy: 0.8450 - val_loss: 0.3542 - val_accuracy: 0.8500
# Epoch 109/200
# 225/225 - 1s - loss: 0.3938 - accuracy: 0.8453 - val_loss: 0.3550 - val_accuracy: 0.8500
# Epoch 110/200
# 225/225 - 1s - loss: 0.3929 - accuracy: 0.8456 - val_loss: 0.3551 - val_accuracy: 0.8500
# Epoch 111/200
# 225/225 - 1s - loss: 0.3900 - accuracy: 0.8472 - val_loss: 0.3550 - val_accuracy: 0.8525
# Epoch 112/200
# 225/225 - 1s - loss: 0.3902 - accuracy: 0.8465 - val_loss: 0.3550 - val_accuracy: 0.8537
# Epoch 113/200
# 225/225 - 1s - loss: 0.3878 - accuracy: 0.8483 - val_loss: 0.3545 - val_accuracy: 0.8487
# Epoch 114/200
# 225/225 - 1s - loss: 0.3905 - accuracy: 0.8469 - val_loss: 0.3546 - val_accuracy: 0.8537
# Epoch 115/200
# 225/225 - 1s - loss: 0.3907 - accuracy: 0.8472 - val_loss: 0.3542 - val_accuracy: 0.8550
# Epoch 116/200
# 225/225 - 1s - loss: 0.3893 - accuracy: 0.8464 - val_loss: 0.3542 - val_accuracy: 0.8525
# Epoch 117/200
# 225/225 - 1s - loss: 0.3845 - accuracy: 0.8472 - val_loss: 0.3533 - val_accuracy: 0.8512
# Epoch 118/200
# 225/225 - 1s - loss: 0.3855 - accuracy: 0.8478 - val_loss: 0.3537 - val_accuracy: 0.8512
# Epoch 119/200
# 225/225 - 1s - loss: 0.3887 - accuracy: 0.8468 - val_loss: 0.3543 - val_accuracy: 0.8512
# Epoch 120/200
# 225/225 - 1s - loss: 0.3909 - accuracy: 0.8465 - val_loss: 0.3547 - val_accuracy: 0.8525
# Epoch 121/200
# 225/225 - 1s - loss: 0.3903 - accuracy: 0.8443 - val_loss: 0.3541 - val_accuracy: 0.8525
# Epoch 122/200
# 225/225 - 1s - loss: 0.3866 - accuracy: 0.8450 - val_loss: 0.3537 - val_accuracy: 0.8537
# Epoch 123/200
# 225/225 - 1s - loss: 0.3885 - accuracy: 0.8478 - val_loss: 0.3531 - val_accuracy: 0.8512
# Epoch 124/200
# 225/225 - 1s - loss: 0.3923 - accuracy: 0.8457 - val_loss: 0.3541 - val_accuracy: 0.8537
# Epoch 125/200
# 225/225 - 1s - loss: 0.3903 - accuracy: 0.8478 - val_loss: 0.3539 - val_accuracy: 0.8537
# Epoch 126/200
# 225/225 - 1s - loss: 0.3891 - accuracy: 0.8457 - val_loss: 0.3538 - val_accuracy: 0.8525
# Epoch 127/200
# 225/225 - 1s - loss: 0.3886 - accuracy: 0.8476 - val_loss: 0.3537 - val_accuracy: 0.8512
# Epoch 128/200
# 225/225 - 1s - loss: 0.3856 - accuracy: 0.8476 - val_loss: 0.3530 - val_accuracy: 0.8500
# Epoch 129/200
# 225/225 - 1s - loss: 0.3895 - accuracy: 0.8479 - val_loss: 0.3541 - val_accuracy: 0.8525
# Epoch 130/200
# 225/225 - 1s - loss: 0.3889 - accuracy: 0.8454 - val_loss: 0.3538 - val_accuracy: 0.8500
# Epoch 131/200
# 225/225 - 1s - loss: 0.3890 - accuracy: 0.8469 - val_loss: 0.3534 - val_accuracy: 0.8537
# Epoch 132/200
# 225/225 - 1s - loss: 0.3927 - accuracy: 0.8465 - val_loss: 0.3541 - val_accuracy: 0.8525
# Epoch 133/200
# 225/225 - 1s - loss: 0.3959 - accuracy: 0.8468 - val_loss: 0.3550 - val_accuracy: 0.8500
# Epoch 134/200
# 225/225 - 1s - loss: 0.3900 - accuracy: 0.8474 - val_loss: 0.3544 - val_accuracy: 0.8500
# Epoch 135/200
# 225/225 - 1s - loss: 0.3905 - accuracy: 0.8467 - val_loss: 0.3548 - val_accuracy: 0.8500
# Epoch 136/200
# 225/225 - 1s - loss: 0.3868 - accuracy: 0.8468 - val_loss: 0.3546 - val_accuracy: 0.8512
# Epoch 137/200
# 225/225 - 1s - loss: 0.3910 - accuracy: 0.8482 - val_loss: 0.3550 - val_accuracy: 0.8512
# Epoch 138/200
# 225/225 - 1s - loss: 0.3858 - accuracy: 0.8494 - val_loss: 0.3537 - val_accuracy: 0.8500
# Epoch 139/200
# 225/225 - 1s - loss: 0.3942 - accuracy: 0.8458 - val_loss: 0.3543 - val_accuracy: 0.8512
# Epoch 140/200
# 225/225 - 1s - loss: 0.3921 - accuracy: 0.8462 - val_loss: 0.3543 - val_accuracy: 0.8512
# Epoch 141/200
# 225/225 - 1s - loss: 0.3870 - accuracy: 0.8442 - val_loss: 0.3538 - val_accuracy: 0.8537
# Epoch 142/200
# 225/225 - 1s - loss: 0.3883 - accuracy: 0.8454 - val_loss: 0.3539 - val_accuracy: 0.8537
# Epoch 143/200
# 225/225 - 1s - loss: 0.3867 - accuracy: 0.8483 - val_loss: 0.3533 - val_accuracy: 0.8525
# Epoch 144/200
# 225/225 - 1s - loss: 0.3880 - accuracy: 0.8471 - val_loss: 0.3532 - val_accuracy: 0.8537
# Epoch 145/200
# 225/225 - 1s - loss: 0.3923 - accuracy: 0.8457 - val_loss: 0.3532 - val_accuracy: 0.8525
# Epoch 146/200
# 225/225 - 1s - loss: 0.3921 - accuracy: 0.8458 - val_loss: 0.3532 - val_accuracy: 0.8550
# Epoch 147/200
# 225/225 - 1s - loss: 0.3897 - accuracy: 0.8449 - val_loss: 0.3535 - val_accuracy: 0.8562
# Epoch 148/200
# 225/225 - 1s - loss: 0.3868 - accuracy: 0.8476 - val_loss: 0.3531 - val_accuracy: 0.8562
# Epoch 149/200
# 225/225 - 1s - loss: 0.3920 - accuracy: 0.8478 - val_loss: 0.3530 - val_accuracy: 0.8550
# Epoch 150/200
# 225/225 - 1s - loss: 0.3926 - accuracy: 0.8482 - val_loss: 0.3528 - val_accuracy: 0.8550
# Epoch 151/200
# 225/225 - 1s - loss: 0.3862 - accuracy: 0.8497 - val_loss: 0.3524 - val_accuracy: 0.8550
# Epoch 152/200
# 225/225 - 1s - loss: 0.3851 - accuracy: 0.8479 - val_loss: 0.3524 - val_accuracy: 0.8562
# Epoch 153/200
# 225/225 - 1s - loss: 0.3883 - accuracy: 0.8467 - val_loss: 0.3524 - val_accuracy: 0.8550
# Epoch 154/200
# 225/225 - 1s - loss: 0.3941 - accuracy: 0.8478 - val_loss: 0.3539 - val_accuracy: 0.8525
# Epoch 155/200
# 225/225 - 1s - loss: 0.3870 - accuracy: 0.8476 - val_loss: 0.3524 - val_accuracy: 0.8537
# Epoch 156/200
# 225/225 - 1s - loss: 0.3903 - accuracy: 0.8462 - val_loss: 0.3530 - val_accuracy: 0.8537
# Epoch 157/200
# 225/225 - 1s - loss: 0.3921 - accuracy: 0.8444 - val_loss: 0.3533 - val_accuracy: 0.8512
# Epoch 158/200
# 225/225 - 1s - loss: 0.3913 - accuracy: 0.8465 - val_loss: 0.3539 - val_accuracy: 0.8537
# Epoch 159/200
# 225/225 - 1s - loss: 0.3884 - accuracy: 0.8486 - val_loss: 0.3534 - val_accuracy: 0.8537
# Epoch 160/200
# 225/225 - 1s - loss: 0.3893 - accuracy: 0.8479 - val_loss: 0.3537 - val_accuracy: 0.8537
# Epoch 161/200
# 225/225 - 1s - loss: 0.3884 - accuracy: 0.8472 - val_loss: 0.3542 - val_accuracy: 0.8525
# Epoch 162/200
# 225/225 - 1s - loss: 0.3856 - accuracy: 0.8479 - val_loss: 0.3534 - val_accuracy: 0.8512
# Epoch 163/200
# 225/225 - 1s - loss: 0.3887 - accuracy: 0.8476 - val_loss: 0.3534 - val_accuracy: 0.8537
# Epoch 164/200
# 225/225 - 2s - loss: 0.3920 - accuracy: 0.8492 - val_loss: 0.3539 - val_accuracy: 0.8512
# Epoch 165/200
# 225/225 - 2s - loss: 0.3943 - accuracy: 0.8464 - val_loss: 0.3540 - val_accuracy: 0.8525
# Epoch 166/200
# 225/225 - 2s - loss: 0.3838 - accuracy: 0.8471 - val_loss: 0.3536 - val_accuracy: 0.8537
# Epoch 167/200
# 225/225 - 2s - loss: 0.3867 - accuracy: 0.8506 - val_loss: 0.3530 - val_accuracy: 0.8512
# Epoch 168/200
# 225/225 - 2s - loss: 0.3955 - accuracy: 0.8468 - val_loss: 0.3534 - val_accuracy: 0.8537
# Epoch 169/200
# 225/225 - 2s - loss: 0.3863 - accuracy: 0.8481 - val_loss: 0.3522 - val_accuracy: 0.8512
# Epoch 170/200
# 225/225 - 2s - loss: 0.3918 - accuracy: 0.8468 - val_loss: 0.3530 - val_accuracy: 0.8525
# Epoch 171/200
# 225/225 - 2s - loss: 0.3888 - accuracy: 0.8474 - val_loss: 0.3527 - val_accuracy: 0.8525
# Epoch 172/200
# 225/225 - 2s - loss: 0.3882 - accuracy: 0.8465 - val_loss: 0.3528 - val_accuracy: 0.8537
# Epoch 173/200
# 225/225 - 2s - loss: 0.3925 - accuracy: 0.8469 - val_loss: 0.3533 - val_accuracy: 0.8487
# Epoch 174/200
# 225/225 - 2s - loss: 0.3855 - accuracy: 0.8501 - val_loss: 0.3525 - val_accuracy: 0.8487
# Epoch 175/200
# 225/225 - 2s - loss: 0.3866 - accuracy: 0.8474 - val_loss: 0.3524 - val_accuracy: 0.8537
# Epoch 176/200
# 225/225 - 2s - loss: 0.3930 - accuracy: 0.8462 - val_loss: 0.3526 - val_accuracy: 0.8537
# Epoch 177/200
# 225/225 - 2s - loss: 0.3901 - accuracy: 0.8492 - val_loss: 0.3526 - val_accuracy: 0.8500
# Epoch 178/200
# 225/225 - 2s - loss: 0.3836 - accuracy: 0.8493 - val_loss: 0.3518 - val_accuracy: 0.8512
# Epoch 179/200
# 225/225 - 2s - loss: 0.3884 - accuracy: 0.8478 - val_loss: 0.3522 - val_accuracy: 0.8487
# Epoch 180/200
# 225/225 - 1s - loss: 0.3950 - accuracy: 0.8467 - val_loss: 0.3539 - val_accuracy: 0.8525
# Epoch 181/200
# 225/225 - 2s - loss: 0.3882 - accuracy: 0.8482 - val_loss: 0.3532 - val_accuracy: 0.8537
# Epoch 182/200
# 225/225 - 2s - loss: 0.3880 - accuracy: 0.8458 - val_loss: 0.3526 - val_accuracy: 0.8525
# Epoch 183/200
# 225/225 - 2s - loss: 0.3932 - accuracy: 0.8464 - val_loss: 0.3531 - val_accuracy: 0.8525
# Epoch 184/200
# 225/225 - 2s - loss: 0.3860 - accuracy: 0.8458 - val_loss: 0.3529 - val_accuracy: 0.8525
# Epoch 185/200
# 225/225 - 2s - loss: 0.3932 - accuracy: 0.8494 - val_loss: 0.3535 - val_accuracy: 0.8512
# Epoch 186/200
# 225/225 - 2s - loss: 0.3859 - accuracy: 0.8512 - val_loss: 0.3528 - val_accuracy: 0.8525
# Epoch 187/200
# 225/225 - 2s - loss: 0.3905 - accuracy: 0.8483 - val_loss: 0.3526 - val_accuracy: 0.8525
# Epoch 188/200
# 225/225 - 2s - loss: 0.3858 - accuracy: 0.8482 - val_loss: 0.3525 - val_accuracy: 0.8512
# Epoch 189/200
# 225/225 - 2s - loss: 0.3901 - accuracy: 0.8471 - val_loss: 0.3526 - val_accuracy: 0.8475
# Epoch 190/200
# 225/225 - 2s - loss: 0.3846 - accuracy: 0.8500 - val_loss: 0.3529 - val_accuracy: 0.8525
# Epoch 191/200
# 225/225 - 2s - loss: 0.3901 - accuracy: 0.8494 - val_loss: 0.3518 - val_accuracy: 0.8500
# Epoch 192/200
# 225/225 - 2s - loss: 0.3911 - accuracy: 0.8454 - val_loss: 0.3523 - val_accuracy: 0.8512
# Epoch 193/200
# 225/225 - 2s - loss: 0.3895 - accuracy: 0.8462 - val_loss: 0.3520 - val_accuracy: 0.8487
# Epoch 194/200
# 225/225 - 2s - loss: 0.3859 - accuracy: 0.8462 - val_loss: 0.3521 - val_accuracy: 0.8525
# Epoch 195/200
# 225/225 - 2s - loss: 0.3923 - accuracy: 0.8489 - val_loss: 0.3518 - val_accuracy: 0.8512
# Epoch 196/200
# 225/225 - 2s - loss: 0.3910 - accuracy: 0.8472 - val_loss: 0.3522 - val_accuracy: 0.8512
# Epoch 197/200
# 225/225 - 1s - loss: 0.3880 - accuracy: 0.8467 - val_loss: 0.3528 - val_accuracy: 0.8537
# Epoch 198/200
# 225/225 - 1s - loss: 0.3902 - accuracy: 0.8479 - val_loss: 0.3519 - val_accuracy: 0.8525
# Epoch 199/200
# 225/225 - 1s - loss: 0.3905 - accuracy: 0.8475 - val_loss: 0.3517 - val_accuracy: 0.8512
# Epoch 200/200
# 225/225 - 1s - loss: 0.3876 - accuracy: 0.8486 - val_loss: 0.3516 - val_accuracy: 0.8512

# %%
type(history)
# Out:
# keras.callbacks.History

# %%
plt.plot(np.array(history.history['accuracy']) * 100)
plt.plot(np.array(history.history['val_accuracy']) * 100)
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'validation'])
plt.title('Accuracy over epochs')
plt.show()

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# [[0.31834784]
#  [0.36277947]
#  [0.16797046]
#  [0.08331715]
#  [0.1084718 ]]

# %%
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1560   35]
#  [ 242  163]]

# %%
print (((cm[0][0]+cm[1][1])*100)/(len(y_test)), '% of testing data was classified correctly')
# Out:
# 86.15 % of testing data was classified correctly
